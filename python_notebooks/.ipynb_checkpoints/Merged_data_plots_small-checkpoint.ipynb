# %%
# %matplotlib inline
import csv
import numpy as np
#impot seaborn as sns; sns.set()
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.pyplot as plt
import matplotlib as mpl
import math

# %%
def remove_outliers(data, pp1, pp2):
    '''
    Based on "Data Outlier Detection using the Chebyshev Theorem",
    Brett G. Amidan, Thomas A. Ferryman, and Scott K. Cooley
    Keyword arguments:
        data -- A numpy array of discrete or continuous data
        pp1 -- likelihood of expected outliers (e.g. 0.1, 0.05 , 0.01)
        pp2 -- final likelihood of real outliers (e.g. 0.01, 0.001 , 0.0001)
    '''

    mu1 = np.mean(data)
    sigma1 = np.std(data)
    k = 1./ np.sqrt(pp1)
    odv1u = mu1 + k * sigma1
    odv1l = mu1 - k * sigma1
    new_data = data[np.where(data <= odv1u)[0]]
    new_data = new_data[np.where(new_data >= odv1l)[0]]
    mu2 = np.mean(new_data)
    sigma2 = np.std(new_data)
    k = 1./ np.sqrt(pp2)
    odv2u = mu2 + k * sigma2
    odv2l = mu2 - k * sigma2
    final_data = new_data[np.where(new_data <= odv2u)[0]]
    final_data = new_data[np.where(final_data >= odv2l)[0]]
    return final_data

# %%
#obtain the loaded data as arrays

def load_data(csv_sheet):
    x = list()
    y = list()
    o = list()
    with open(csv_sheet, 'rb') as f:
        reader = csv.reader(f)
        for row in reader:
            x.append(float(row[0]))
            y.append(float(row[1]))
            o.append(float(row[2]))
        
    x = np.array(x)
    y = np.array(y)
    o = np.array(o)
    return x,y,o

# %%
#plot the distribution after outlier removal
def gaussian_plot(x_, y_, o_):
    sns.distplot(x_, hist=False, rug=True, kde_kws={"shade": True})
    plt.xlabel('X coordinate of pose (cm)')
    plt.show()
    sns.distplot(y_, hist=False, rug =True, kde_kws={"shade": True})
    plt.xlabel('Y coordinate of pose (cm)')
    plt.show()
    sns.distplot(o_, hist=False, rug=True, kde_kws={"shade": True})
    plt.xlabel('Orientation in radians')
    plt.show()

def return_sigma(distribution):
    var = np.var(distribution)
    return math.sqrt(var)

def return_mean(distribution):
    return np.mean(distribution)

def scattered_plot(x_, y_, o_):
    N = 164
    area = (10 * np.random.rand(N))**2
    z = np.random.rand(N)
    
    plt.figure(figsize=(8, 6))
    
    for i in range(len(o_)):
        angle = np.degrees(o_[i])
        t = mpl.markers.MarkerStyle(marker=">")
        t._transform = t.get_transform().rotate_deg(angle)
        axarr[0].scatter(x_, y_, alpha=0.5, c=z, s=area, marker=t)
    axarr[0].set_xlabel('Scattered X and Y coordinates (cms) with the orientation(degree) of poses')
    axarr[0].set_title('Scatter plot for straight placement of small marker')
    
    axarr[1].scatter(x_, y_, alpha=0.5, c=z, s=area, marker=(3, 0, np.mean(o_)))
    axarr[1].set_xlabel('Scattered X and Y coordinates (cms) of with mean orientation in poses')
    axarr[1].set_title('Scatter plot for straight placement of small marker')
    f.subplots_adjust(hspace=0.2)
    plt.show()

# %%
#Obtain the merged data

#small marker-straight
small_str = 'merged_data/small_straight.csv'
small_str_x, small_str_y, small_str_o = load_data(small_str)

#small marker-left
small_left = 'merged_data/small_left.csv'
small_left_x, small_left_y, small_left_o = load_data(small_left)

#small marker-right
small_right = 'merged_data/small_right.csv'
small_right_x, small_right_y, small_right_o = load_data(small_right)

# %%
print "Gaussian plots before removal of outliers"
gaussian_plot(small_str_x, small_str_y, small_str_o)
sigma = return_sigma(small_str_x)
print sigma
# Out:
# Gaussian plots before removal of outliers
# 11.1542305238

# %%
print "Experiment: Grasping Small marker"'\n'"Placing: Straight"
scattered_plot(small_str_x, small_str_y, small_str_o)
# Out:
# Experiment: Grasping Small marker
# Placing: Straight

# %%
print "Experiment: Grasping Small marker"'\n'"Placing: Left"
scattered_plot(small_left_x, small_left_y, small_left_o)
print "Experiment: Grasping Small marker"'\n'"Placing: Right"
scattered_plot(small_right_x, small_right_y, small_right_o)
# Out:
# Experiment: Grasping Small marker
# Placing: Left
# Experiment: Grasping Small marker
# Placing: Right
